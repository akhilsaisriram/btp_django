# %%
X_data = []
y_data = []
t_data=[]

# %%
import os
import pandas as pd

# Define the directory path
directory_path = "/content/drive/MyDrive/emg_data_all_anish/emg_concatenated_pramod"

# Get the list of file names in the directory
file_names = os.listdir(directory_path)

# Sort the file names based on the number at the beginning
sorted_file_names = sorted(file_names, key=lambda x: int(x.split("_")[0]))

# Initialize empty lists to store X and y data

# Iterate through each file in the sorted list
for file_name in sorted_file_names:
    # Construct the full file path
    file_path = os.path.join(directory_path, file_name)

    # Check if the path corresponds to a file (not a directory)
    if os.path.isfile(file_path):
        # Read the CSV file into a DataFrame
        df = pd.read_csv(file_path)

        # Extract features (X) and target variable (y)
        X = df.iloc[:, :-2]  # All columns except the last two
        y = df.iloc[:, -1]   # Last column
        k= df.iloc[:, :]
        t_data.append( k)
        # Append the data to the lists
        X_data.append(X)
        y_data.append(y)

# Concatenate X and y data along rows

# Print the shape of X and y

# %%
import os
import pandas as pd

# Define the directory path
directory_path = "/content/drive/MyDrive/emg_data_all_anish/emg_concatenated_kamal"

# Get the list of file names in the directory
file_names = os.listdir(directory_path)

# Sort the file names based on the number at the beginning
sorted_file_names = sorted(file_names, key=lambda x: int(x.split("_")[0]))

# Initialize empty lists to store X and y data

# Iterate through each file in the sorted list
for file_name in sorted_file_names:
    # Construct the full file path
    file_path = os.path.join(directory_path, file_name)

    # Check if the path corresponds to a file (not a directory)
    if os.path.isfile(file_path):
        # Read the CSV file into a DataFrame
        df = pd.read_csv(file_path)

        # Extract features (X) and target variable (y)
        X = df.iloc[:, :-2]  # All columns except the last two
        y = df.iloc[:, -1]   # Last column
        k= df.iloc[:, :]
        t_data.append( k)
        # Append the data to the lists
        X_data.append(X)
        y_data.append(y)

# Concatenate X and y data along rows

# Print the shape of X and y

# %%
import os
import pandas as pd

# Define the directory path
directory_path = "/content/drive/MyDrive/emg_data_all_anish/emg_concatenated_rohan"

# Get the list of file names in the directory
file_names = os.listdir(directory_path)

# Sort the file names based on the number at the beginning
sorted_file_names = sorted(file_names, key=lambda x: int(x.split("_")[0]))

# Initialize empty lists to store X and y data

# Iterate through each file in the sorted list
for file_name in sorted_file_names:
    # Construct the full file path
    file_path = os.path.join(directory_path, file_name)

    # Check if the path corresponds to a file (not a directory)
    if os.path.isfile(file_path):
        # Read the CSV file into a DataFrame
        df = pd.read_csv(file_path)

        # Extract features (X) and target variable (y)
        X = df.iloc[:, :-2]  # All columns except the last two
        y = df.iloc[:, -1]   # Last column
        k= df.iloc[:, :]
        t_data.append( k)
        # Append the data to the lists
        X_data.append(X)
        y_data.append(y)

# Concatenate X and y data along rows

# Print the shape of X and y

# %%
import os
import pandas as pd

# Define the directory path
directory_path = "/content/drive/MyDrive/emg_data_all_anish/emg_concatenated_eswar"

# Get the list of file names in the directory
file_names = os.listdir(directory_path)

# Sort the file names based on the number at the beginning
sorted_file_names = sorted(file_names, key=lambda x: int(x.split("_")[0]))

# Initialize empty lists to store X and y data

# Iterate through each file in the sorted list
for file_name in sorted_file_names:
    # Construct the full file path
    file_path = os.path.join(directory_path, file_name)

    # Check if the path corresponds to a file (not a directory)
    if os.path.isfile(file_path):
        # Read the CSV file into a DataFrame
        df = pd.read_csv(file_path)

        # Extract features (X) and target variable (y)
        X = df.iloc[:, :-2]  # All columns except the last two
        y = df.iloc[:, -1]   # Last column
        k= df.iloc[:, :]
        t_data.append( k)
        # Append the data to the lists
        X_data.append(X)
        y_data.append(y)

# Concatenate X and y data along rows

# Print the shape of X and y

# %%
len(t_data)
# Out:
# 196

# %%
ffa=[]
for i in range(len(t_data)):
  # print(X_data_main[i].head())
  x=pd.DataFrame(t_data[i])
  df_new=x[(x['signal']>=x.iloc[1,0]+3.5) & (x['signal']<=x.iloc[1,0]+8.8)]

  ffa.append(df_new)

# %%
len(ffa)
# Out:
# 196

# %%
for obj in ffa:

    print("Columns:", len(obj.columns))
    print("Rows:", len(obj))
    print("======================")
# Out:
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...
# Columns: 8
# Rows: 10601
# ...

# %%
import numpy as np
import pandas as pd
win = []
def sliding_window(ffa, window_size=530):
    # Initialize an empty list to store the windows


    # Assuming your DataFrame is named signal and the time column is named 'time'
    signal = ffa

    # Convert time to milliseconds
    signal['time_ms'] = signal['signal'] * 1000

    # Calculate the number of samples in each window
    samples_per_window = int(window_size / (signal['time_ms'].iloc[1] - signal['time_ms'].iloc[0]))

    # Iterate through the data frame with a sliding window
    for i in range(0, len(signal) - samples_per_window + 1, samples_per_window):
        # Extract the window of data
        window_data = signal.iloc[i:i+samples_per_window, :]
        # Append the window to the list
        win.append(window_data)



# Call the function with ffa as input

# %%
for obj in ffa:
    sliding_window(obj)



# Check the length of the list of windows
print(len(win))
# Out:
# 1960
# <ipython-input-11-3ed589d45506>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   signal['time_ms'] = signal['signal'] * 1000

# %%
win[488]
# Out:
#          signal  Ultium EMG-BRACHIORAD. RT  Ultium EMG-EXT.CARP.ULN. RT  \
# 15481  535.7005                  92.143545                   -59.745351
# 15482  535.7010                  99.468211                   -30.446688
# 15483  535.7015                  93.059128                   -21.901245
# 15484  535.7020                  71.085131                    -0.232442
# 15485  535.7025                  32.630636                    44.325942
# ...         ...                        ...                          ...
# 16536  536.2280                  37.513746                   -49.979130
# 16537  536.2285                  29.273497                   -12.745413
# 16538  536.2290                  10.961833                    38.222053
# 16539  536.2295                  -7.655026                    79.118104
# 16540  536.2300                 -18.947219                   108.416767
#
#        Ultium EMG-EXT.DIG. RT  Ultium EMG-FLEX.CAPR.U RT  \
# ...

# %%
win[489]
# Out:
#          signal  Ultium EMG-BRACHIORAD. RT  Ultium EMG-EXT.CARP.ULN. RT  \
# 16541  536.2305                 -26.271885                   124.286876
# 16542  536.2310                 -39.395245                   113.299878
# 16543  536.2315                 -54.654965                    73.929799
# 16544  536.2320                 -55.875743                    28.150638
# 16545  536.2325                 -34.206940                   -10.303857
# ...         ...                        ...                          ...
# 17596  536.7580                 -34.817328                   -19.764884
# 17597  536.7585                 -29.018635                   -13.355801
# 17598  536.7590                 -31.765384                    -4.199969
# 17599  536.7595                 -36.343300                     3.124697
# 17600  536.7600                 -38.479661                     6.481835
#
#        Ultium EMG-EXT.DIG. RT  Ultium EMG-FLEX.CAPR.U RT  \
# ...

# %%
from scipy.stats import skew, kurtosis
from scipy.signal import find_peaks

def compute_features(signal_numeric):
    # Drop columns 'signal', 'class', 'division', and 'time_ms'
    # signal = signal.drop(columns=['signal', 'class', 'division', 'time_ms'])

    # # Convert signal DataFrame to numeric values
    # signal_numeric = signal.apply(pd.to_numeric, errors='coerce')
    # signal_numeric.dropna(inplace=True)  # Drop rows with NaN values

    # Compute mean value
    mean_value = np.mean(signal_numeric)

    # Compute standard deviation
    std_dev = np.std(signal_numeric)

    # Compute maximum value
    max_value = np.max(signal_numeric)

    # Compute minimum value
    min_value = np.min(signal_numeric)

    # Compute skewness
    skewness = skew(signal_numeric)

    # Compute kurtosis
    kurtosis_value = kurtosis(signal_numeric)

    # Compute median
    median_value = np.median(signal_numeric)

    # Compute line length
    line_length = np.sum(np.abs(np.diff(signal_numeric)))

    # Compute mean of vertex-to-vertex amplitudes
    vv_ampl_mean = np.mean(np.abs(np.diff(signal_numeric)))

    # Compute variance of vertex-to-vertex amplitudes
    vv_ampl_var = np.var(np.abs(np.diff(signal_numeric)))

    # Compute mean of vertex-to-vertex times
    vv_time_mean = np.mean(np.diff(signal_numeric))

    # Compute variance of vertex-to-vertex times
    vv_time_var = np.var(np.diff(signal_numeric))

    # # Compute mean of vertex-to-vertex slope
    # vv_slope_mean = np.mean(np.diff(signal_numeric) / np.diff(range(len(signal_numeric))))

    # # Compute variance of vertex-to-vertex slope
    # vv_slope_var = np.var(np.diff(signal_numeric) / np.diff(range(len(signal_numeric) - 1)))

    # Compute number of zero crossings
    zero_crossings = np.sum(np.diff(np.sign(signal_numeric)) != 0)

    # Compute number of local minima and maxima
    # peaks, _ = find_peaks(signal_numeric)
    # valleys, _ = find_peaks(-signal_numeric)
    # min_max_number = len(peaks) + len(valleys)

    # Compute amplitude range
    ampl_range = np.max(signal_numeric) - np.min(signal_numeric)

    # Calculate first derivative
    first_derivative = np.gradient(signal_numeric)

    # Calculate second derivative
    second_derivative = np.gradient(first_derivative)

    # Compute mean value of the first derivative
    first_diff_mean = np.mean(first_derivative)

    # Compute maximum value of the first derivative
    first_diff_max = np.max(first_derivative)

    # Compute mean value of the second derivative
    second_diff_mean = np.mean(second_derivative)

    # Compute maximum value of the second derivative
    second_diff_max = np.max(second_derivative)

    # Compute Hjorth Parameter 1: Activity
    hjorth_activity = np.var(signal_numeric)

    # Compute Hjorth Parameter 2: Mobility
    hjorth_mobility = np.std(first_derivative) / np.std(signal_numeric)

    # Compute Hjorth Parameter 3: Complexity
    hjorth_complexity = np.std(second_derivative) / np.std(first_derivative)

    # Compute FFT
    fft_result = np.fft.fft(signal_numeric)
    fs = 1 / 0.8  # Sampling frequency
    freqs = np.fft.fftfreq(len(fft_result), 1 / fs)  # Frequency axis

    # Define frequency bands
    delta_indices = np.where((freqs >= 0.1) & (freqs <= 3))[0]

    # Compute delta power
    delta_power = np.sum(np.abs(fft_result[delta_indices]) ** 2)

    # Append all features to a list
    features = [
        mean_value, std_dev, max_value, min_value, skewness, kurtosis_value,
        median_value, line_length, vv_ampl_mean, vv_ampl_var, vv_time_mean,
        vv_time_var,  zero_crossings,
        ampl_range, first_diff_mean, first_diff_max, second_diff_mean,
        second_diff_max, hjorth_activity, hjorth_mobility, hjorth_complexity,
        delta_power
    ]

    return features

# Example usage:
# features = compute_features(win[1])

# %%
import pandas as pd
win_futures=[]
def process_win(win):
    # Create an empty DataFrame to store the computed features
    features_df = pd.DataFrame()
    division_values = win['division'].drop_duplicates()

    ii = win.drop(columns=['signal', 'class', 'division', 'time_ms'])

    # Convert signal DataFrame to numeric values
    ii = ii.apply(pd.to_numeric, errors='coerce')
    ii.dropna(inplace=True)  # Drop rows with NaN values

    # Iterate over each column in the DataFrame
    for col in ii.columns:
        # Compute features for the current column
        col_features = compute_features(ii[col])

        # Add the computed features as a new column in the features DataFrame
        features_df[col] = col_features

    # Concatenate the computed features DataFrame with one_row_df
    one_row_df = pd.concat([features_df[col] for col in features_df.columns], axis=0).to_frame().T
    one_row_df['label'] = division_values.iloc[0]

    # Append one_row_df to existing_df
    win_futures.append(one_row_df)



# Call the function with win as input

# %%
for obj in win:
  process_win(obj)

# %%
(win_futures[0])
# Out:
#           0          1           2           3         4          5         6  \
# 0  1.066336  52.649932  438.844392 -377.855843  0.226415  19.440333 -0.025166
#
#             7        8           9  ...           13        14          15  \
# 0  8878.10532  8.38348  217.991422  ...  1151.803695  0.057152  206.769211
#
#          16         17           18        19        20            21  \
# 0 -0.003383  55.850577  6420.638495  0.302481  0.484906  1.867635e+08
#
#       label
# 0  Pointing
#
# [1 rows x 111 columns]

# %%
existing_dfa = pd.concat(win_futures, ignore_index=True)

# Save the DataFrame as a CSV file
existing_dfa.to_csv('existing_data_all.csv', index=False)

# %%
df = pd.read_csv('existing_data_all.csv')

# Separate features (X) and target variable (y)
X = df.iloc[:, :-1]  # Select all columns except the last one as features
y = df.iloc[:, -1]   # Select the last column as the target variable

# %%
y
# Out:
# 0        Pointing
# 1        Pointing
# 2        Pointing
# 3        Pointing
# 4        Pointing
#           ...
# 1955    Ok_symbol
# 1956    Ok_symbol
# 1957    Ok_symbol
# 1958    Ok_symbol
# 1959    Ok_symbol
# Name: label, Length: 1960, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
import json

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the target variable y
y_encoded = label_encoder.fit_transform(y)

# Save the label encoding mapping
label_mapping = {label: int(encoded_label) for label, encoded_label in zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_))}

# Save the label mapping as a dictionary
with open('label_mapping_all.json', 'w') as f:
    json.dump(label_mapping, f)

# %%
y_encoded
# Out:
# array([4, 4, 4, ..., 3, 3, 3])

# %%
len(X)
# Out:
# 1960

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
pca = PCA()
pca_result = pca.fit(X)

# Plot the scree plot to visualize explained variance per component
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(pca.explained_variance_ratio_) + 1), np.cumsum(pca.explained_variance_ratio_), marker='o')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Scree Plot')
plt.grid(True)
plt.show()

print(len(pca.explained_variance_ratio_))
# Out:
# 110

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler,normalize
from sklearn.metrics import accuracy_score
import pandas as pd



X_scaled=normalize(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

# %%
rf_model = RandomForestClassifier(n_estimators=200)
rf_model.fit(X_train, y_train)

# Step 7: Evaluate Model
y_pred = rf_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8494897959183674

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn import metrics
import matplotlib.pyplot as plt

# Generate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=np.unique(y_test))
cm_display.plot()
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Generate classification report
class_report = classification_report(y_test, y_pred)
print("Classification Report:")
print(class_report)
# Out:
# Confusion Matrix:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.85      0.68        34
#            1       0.94      0.81      0.87        63
#            2       0.98      0.81      0.89        59
#            3       0.89      0.88      0.89        67
#            4       0.78      0.85      0.81        59
#            5       0.80      0.79      0.79        56
#            6       0.98      0.96      0.97        54
#
#     accuracy                           0.85       392
#    macro avg       0.85      0.85      0.84       392
# weighted avg       0.87      0.85      0.85       392

# %%
# !pip install catboost
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 MB 3.7 MB/s eta 0:00:00
# ...

# %%
from catboost import CatBoostClassifier
catboost_model = CatBoostClassifier()
catboost_model.fit(X_train, y_train)

# Step 6: Evaluate Model
y_preda = catboost_model.predict(X_test)
accuracya = accuracy_score(y_test, y_preda)
print("Accuracy:", accuracya)
# Out:
# Learning rate set to 0.080963
# 0:	learn: 1.8568047	total: 692ms	remaining: 11m 31s
# 1:	learn: 1.7782197	total: 1.25s	remaining: 10m 21s
# 2:	learn: 1.7141363	total: 1.72s	remaining: 9m 31s
# 3:	learn: 1.6488216	total: 2.18s	remaining: 9m 2s
# 4:	learn: 1.5945582	total: 2.75s	remaining: 9m 6s
# 5:	learn: 1.5488898	total: 3.22s	remaining: 8m 53s
# 6:	learn: 1.5093553	total: 3.62s	remaining: 8m 33s
# 7:	learn: 1.4766630	total: 3.95s	remaining: 8m 10s
# 8:	learn: 1.4427937	total: 4.3s	remaining: 7m 53s
# 9:	learn: 1.4037002	total: 4.62s	remaining: 7m 36s
# 10:	learn: 1.3649373	total: 4.88s	remaining: 7m 18s
# 11:	learn: 1.3333457	total: 5.15s	remaining: 7m 3s
# 12:	learn: 1.2925535	total: 5.3s	remaining: 6m 42s
# 13:	learn: 1.2622289	total: 5.46s	remaining: 6m 24s
# 14:	learn: 1.2382081	total: 5.61s	remaining: 6m 8s
# 15:	learn: 1.2089457	total: 5.75s	remaining: 5m 53s
# 16:	learn: 1.1854930	total: 5.89s	remaining: 5m 40s
# 17:	learn: 1.1595647	total: 6.05s	remaining: 5m 29s
# ...

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn import metrics
import matplotlib.pyplot as plt

# Generate confusion matrix
conf_matrix = confusion_matrix(y_test, y_preda)
print("Confusion Matrix:")
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=np.unique(y_test))
cm_display.plot()
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Generate classification report
class_report = classification_report(y_test, y_preda)
print("Classification Report:")
print(class_report)
# Out:
# Confusion Matrix:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.64      0.94      0.76        34
#            1       0.93      0.86      0.89        63
#            2       0.95      0.92      0.93        59
#            3       0.97      0.85      0.90        67
#            4       0.82      0.92      0.86        59
#            5       0.94      0.84      0.89        56
#            6       1.00      0.96      0.98        54
#
#     accuracy                           0.89       392
#    macro avg       0.89      0.90      0.89       392
# weighted avg       0.91      0.89      0.90       392

# %%
from xgboost import XGBClassifier
xgb_model = XGBClassifier()
xgb_model.fit(X_train, y_train)

y_predaa = xgb_model.predict(X_test)
accuracy = accuracy_score(y_test, y_predaa)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8877551020408163

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn import metrics
import matplotlib.pyplot as plt

# Generate confusion matrix
conf_matrix = confusion_matrix(y_test, y_predaa)
print("Confusion Matrix:")
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=np.unique(y_test))
cm_display.plot()
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Generate classification report
class_report = classification_report(y_test, y_predaa)
print("Classification Report:")
print(class_report)
# Out:
# Confusion Matrix:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.65      0.97      0.78        34
#            1       0.98      0.86      0.92        63
#            2       0.95      0.88      0.91        59
#            3       0.92      0.87      0.89        67
#            4       0.85      0.88      0.87        59
#            5       0.89      0.84      0.86        56
#            6       0.96      0.96      0.96        54
#
#     accuracy                           0.89       392
#    macro avg       0.89      0.89      0.88       392
# weighted avg       0.90      0.89      0.89       392
